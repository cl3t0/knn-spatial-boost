# %% [markdown]
# # Study

# %%
#| hide
import pandas as pd
import numpy as np
import datetime
import typing as t
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import pickle

# %%
#| hide
np.random.seed(42)

# %% [markdown]
# I want to predict future prices for houses. To do it my plan is to build a model to predict price given a set of features (like number of rooms, square footage, etc) and a date in the range of my data (2013 to 2016) and another model to build this forecast to current prices (2023). Heres my [initial dataset](https://www.kaggle.com/datasets/devvret/brazil-real-estate-listings/).

# %%
raw_df = pd.read_csv("properati-BR-2016-11-01-properties-sell.csv")

# %% [markdown]
# ## Data cleaning
#
# The dataset has a lot of columns but I'm going to use only a subset of them.
#
# - created_on
# - property_type
# - lat
# - lon
# - price
# - surface_covered_in_m2
# - rooms
# - description

# %%
df = raw_df[
    raw_df["created_on"].notnull()
    & raw_df.lat.notnull()
    & raw_df.lon.notnull()
    & raw_df.price.notnull()
    & raw_df.rooms.notnull()
    & raw_df.surface_covered_in_m2.notnull()
    & (raw_df.surface_covered_in_m2 > 0)
    & (raw_df.surface_covered_in_m2 < 5000)
    & (raw_df.currency == "BRL")
][
    [
        "lat",
        "lon",
        "created_on",
        "property_type",
        "price",
        "surface_covered_in_m2",
        "rooms",
        "description"
    ]
]
df.created_on = pd.to_datetime(df.created_on)
df.head(3)
# Out:
#            lat        lon created_on property_type      price  \
# 792  -3.474983 -38.928616 2013-06-26         house  5000000.0
# 794 -23.547697 -46.657379 2013-09-04     apartment  2000000.0
# 795 -23.545349 -46.659519 2013-09-04     apartment   960000.0
#
#      surface_covered_in_m2  rooms  \
# 792                 1000.0    8.0
# 794                  180.0    3.0
# 795                  109.0    3.0
#
#                                            description
# 792  Casa de praia em Taíba, a apenas 67 km de Fort...
# 794  EXCELENTE OPORTUNIDADE!!\n\nAPARTAMENTO TOTALM...
# 795  IMOVEL SITO NA RUA ALAGOAS, BEM LOCALIZADO, EM...

# %% [markdown]
# I would love to use "floor" and "surface_total_in_m2" as features but they are filled for less then 10% for the dataset. The "description" column wasn't dropped to enable single row analysis to identify anomalies or outliers. In the future it can be used with NLP to improve price prediction accuracy.

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 872672 entries, 0 to 872671
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   created_on                  872672 non-null  object
#  1   operation                   872672 non-null  object
#  2   property_type               872672 non-null  object
#  3   place_name                  872672 non-null  object
#  4   place_with_parent_names     872672 non-null  object
#  5   geonames_id                 140 non-null     float64
#  6   lat-lon                     387227 non-null  object
#  7   lat                         387227 non-null  float64
#  8   lon                         387227 non-null  float64
#  9   price                       819401 non-null  float64
#  10  currency                    819382 non-null  object
#  11  price_aprox_local_currency  819401 non-null  float64
#  12  price_aprox_usd             819401 non-null  float64
#  13  surface_total_in_m2         216934 non-null  float64
#  14  surface_covered_in_m2       633240 non-null  float64
#  15  price_usd_per_m2            589181 non-null  float64
#  16  price_per_m2                589181 non-null  float64
#  17  floor                       50794 non-null   float64
#  18  rooms                       541746 non-null  float64
#  19  expenses                    233318 non-null  float64
#  20  properati_url               872672 non-null  object
#  21  description                 872672 non-null  object
#  22  title                       872672 non-null  object
#  23  image_thumbnail             834007 non-null  object
# dtypes: float64(13), object(11)
# memory usage: 159.8+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 161731 entries, 792 to 872667
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   lat                    161731 non-null  float64
#  1   lon                    161731 non-null  float64
#  2   created_on             161731 non-null  datetime64[ns]
#  3   property_type          161731 non-null  object
#  4   price                  161731 non-null  float64
#  5   surface_covered_in_m2  161731 non-null  float64
#  6   rooms                  161731 non-null  float64
#  7   description            161731 non-null  object
# dtypes: datetime64[ns](1), float64(5), object(2)
# memory usage: 11.1+ MB

# %% [markdown]
# Here's a geographical view of the data. For viewing purposes we are limiting the price and for future comparison we are going to "zoom in" Belo Horizonte (BH), which is a big city, filter to only apartments with 1 room and square footage between 60 and 80.

# %%
bh_lats = (-19.99491, -19.83163)
bh_longs = (-44.02857, -43.90612)
price_limit = 900000

# %%
bh_df = df[
    (df.lat > bh_lats[0])
    & (df.lat < bh_lats[1])
    & (df.lon > bh_longs[0])
    & (df.lon < bh_longs[1])
    & (df.property_type == "apartment")
    & (df.surface_covered_in_m2 > 60)
    & (df.surface_covered_in_m2 < 80)
    & (df.rooms == 1)
]
bh_df.loc[bh_df.price > price_limit, "price"] = price_limit
plt.scatter(
    bh_df["lon"],
    bh_df["lat"],
    s=20,
    c=bh_df["price"],
    cmap="plasma_r",
    alpha=0.8
)
plt.colorbar()
plt.show()

# %% [markdown]
# ## Data preprocessing
#
# To prepare our data to machine learning model, we need to parse categorial features into numbers. To do it, we are using one hot encoding.

# %%
def prepare_one_hots(x: pd.DataFrame) -> pd.DataFrame:
    x.loc[:, "is_house"] = 0
    x.loc[x.property_type == "house", "is_house"] = 1

    x.loc[:, "is_apartment"] = 0
    x.loc[x.property_type == "apartment", "is_apartment"] = 1

    x.loc[:, "is_PH"] = 0
    x.loc[x.property_type == "PH", "is_PH"] = 1

    x.loc[:, "is_store"] = 0
    x.loc[x.property_type == "store", "is_store"] = 1

    x.drop(columns=["property_type"], inplace=True)
    return x

def prepare(x: pd.DataFrame) -> pd.DataFrame:
    new_x = x.copy()
    new_x.created_on = new_x.created_on.map(datetime.datetime.toordinal)
    new_x.drop(columns=["description"], inplace=True)
    return prepare_one_hots(new_x)

prepared_df = prepare(df)
prepared_df.head(3)
# Out:
#            lat        lon  created_on      price  surface_covered_in_m2  \
# 792  -3.474983 -38.928616      735045  5000000.0                 1000.0
# 794 -23.547697 -46.657379      735115  2000000.0                  180.0
# 795 -23.545349 -46.659519      735115   960000.0                  109.0
#
#      rooms  is_house  is_apartment  is_PH  is_store
# 792    8.0         1             0      0         0
# 794    3.0         0             1      0         0
# 795    3.0         0             1      0         0

# %% [markdown]
# Before start training, we are going to split our dataset into training dataset and validation dataset.

# %%
def split_dataset(
    dataset: pd.DataFrame, test_ratio: float = 0.30
) -> t.Tuple[pd.DataFrame, pd.DataFrame]:
    test_indices = np.random.rand(len(dataset)) < test_ratio
    return dataset[~test_indices], dataset[test_indices]

train, valid = split_dataset(prepared_df)
X_train = train.loc[:, train.columns != "price"].to_numpy()
y_train = train.price.to_numpy()
X_valid = valid.loc[:, valid.columns != "price"].to_numpy()
y_valid = valid.price.to_numpy()
print(X_train.shape)
print(y_train.shape)
print(X_valid.shape)
print(y_valid.shape)
# Out:
# (113286, 9)
# (113286,)
# (48445, 9)
# (48445,)

# %% [markdown]
# ## Sanity checks
#
# Even with the validation dataset we want to make some sanity checks after the training. To do it so, we built this function which evaluates the model with specific features. It's a *curried* function because there are some standarized checks to apply to all models.

# %%
def eval(
    lat: t.Union[float, np.ndarray],
    lon: t.Union[float, np.ndarray],
    created_on: t.Union[datetime.date, t.List[datetime.date]],
    property_type: t.Literal["apartment", "house"],
    surface_covered_in_m2: t.Union[float, np.ndarray],
    rooms: t.Union[int, np.ndarray]
) -> t.Callable[[t.Any], pd.DataFrame]:

    lat_vec = lat if isinstance(lat, np.ndarray) else np.array([lat])
    lon_vec = lon if isinstance(lon, np.ndarray) else np.array([lon])
    created_on_vec = (
        np.array([c.toordinal() for c in created_on])
        if isinstance(created_on, t.List)
        else np.array([created_on.toordinal()])
    )
    surface_covered_in_m2_vec = (
        surface_covered_in_m2
        if isinstance(surface_covered_in_m2, np.ndarray)
        else np.array([surface_covered_in_m2])
    )
    rooms_vec = rooms if isinstance(rooms, np.ndarray) else np.array([rooms])

    m = np.vstack(
        [v.ravel() for v in np.meshgrid(
            lat_vec,
            lon_vec,
            created_on_vec,
            surface_covered_in_m2_vec,
            rooms_vec,
            indexing="ij"
        )]
    ).T

    x_df = prepare_one_hots(pd.DataFrame(
        {
            "lat": m[:, 0],
            "lon": m[:, 1],
            "created_on": m[:, 2],
            "property_type": [property_type] * len(m),
            "surface_covered_in_m2": m[:, 3],
            "rooms": m[:, 4]
        }
    ))
    x = x_df.to_numpy()

    def fn(model: t.Any) -> pd.DataFrame:
        y = model.predict(x)
        x_df["price"] = y.reshape(len(m))
        x_df.price = x_df.price.round(2)
        return x_df
    return fn

# %% [markdown]
# Here's all sanity checks:

# %%
lats, longs = np.linspace(bh_lats[0], bh_lats[1], 100), np.linspace(bh_longs[0], bh_longs[1], 50)

santacruz = (-19.87755, -43.94184)
sion = (-19.95408, -43.93163)

start = datetime.date(2013, 7, 1)
date_list = [start + datetime.timedelta(days=x) for x in range(365*3)]

bh_heatmap_check = eval(lats, longs, datetime.date(2016, 1, 1), "apartment", 70, 1)
santa_cruz_price_evolution = eval(santacruz[0], santacruz[1], date_list, "apartment", 70, np.array([1, 2, 3]))
sion_price_evolution = eval(sion[0], sion[1], date_list, "apartment", 70, np.array([1, 2, 3]))

# %% [markdown]
# Here's a function to plot everything once:

# %%
def sanity_checks(model: t.Any, set_color_bounds: bool = False) -> None:
    bh_heatmap = bh_heatmap_check(model)
    santa_cruz = santa_cruz_price_evolution(model)
    sion = sion_price_evolution(model)

    bh_heatmap.loc[bh_heatmap.price > price_limit, "price"] = price_limit

    fig, ax = plt.subplots(3, figsize=(5, 15))

    ax[0].title.set_text("BH price heatmap")
    scatter = ax[0].scatter(
        bh_heatmap["lon"],
        bh_heatmap["lat"],
        s=20,
        c=bh_heatmap["price"],
        cmap="plasma_r",
        alpha=0.8,
        **({"norm": colors.Normalize(vmin=0,vmax=price_limit)} if set_color_bounds else {})
    )
    fig.colorbar(scatter)

    ax[1].title.set_text("Santa Cruz price evolution")
    ax[1].plot(date_list, santa_cruz[santa_cruz.rooms == 1].price.rolling(30).mean(), label="1 room")
    ax[1].plot(date_list, santa_cruz[santa_cruz.rooms == 2].price.rolling(30).mean(), label="2 rooms")
    ax[1].plot(date_list, santa_cruz[santa_cruz.rooms == 3].price.rolling(30).mean(), label="3 rooms")
    ax[1].legend()
    plt.setp(ax[1].get_xticklabels(), rotation=30, horizontalalignment='right')

    ax[2].title.set_text("Sion price evolution")
    ax[2].plot(date_list, sion[sion.rooms == 1].price.rolling(30).mean(), label="1 room")
    ax[2].plot(date_list, sion[sion.rooms == 2].price.rolling(30).mean(), label="2 rooms")
    ax[2].plot(date_list, sion[sion.rooms == 3].price.rolling(30).mean(), label="3 rooms")
    ax[2].legend()
    plt.setp(ax[2].get_xticklabels(), rotation=30, horizontalalignment='right')

    fig.show()

# %% [markdown]
# ## Random Forest
#
# We are going to give a try to the Random Forest model.

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
#| notest
rf = RandomForestRegressor(max_depth=10, random_state=0)

rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, random_state=0)

# %%
#| hide
pickle.dump(rf, open("rf.pickle", "wb"))

# %%
#| hide
rf = pickle.load(open("rf.pickle", "rb"))

# %%
rf.score(X_valid, y_valid)
# Out:
# 0.7125046159284849

# %%
sanity_checks(rf)
# Out:
# /tmp/ipykernel_121093/2726626927.py:36: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## KNN
#
# We are going to give a try to KNN.

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
#| notest
knn = KNeighborsRegressor(n_neighbors=7, weights="distance")
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=7, weights='distance')

# %%
#| hide
pickle.dump(knn, open("knn.pickle", "wb"))

# %%
#| hide
knn = pickle.load(open("knn.pickle", "rb"))

# %%
knn.score(X_valid, y_valid)
# Out:
# 0.4476726937780481

# %%
sanity_checks(knn)
# Out:
# /tmp/ipykernel_121093/2726626927.py:36: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Neural Networks
#
# We are going to give a try to neural networks.

# %%
from sklearn.neural_network import MLPRegressor

# %%
#| notest
nn = MLPRegressor(
    hidden_layer_sizes=(64, 32, 16, 8),
    verbose=True,
    max_iter=200,
    batch_size=32,
    early_stopping=True,
    random_state=0
)

nn.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 989008557475.24633789
# Validation score: 0.000894
# Iteration 2, loss = 982935525969.45141602
# Validation score: 0.002829
# Iteration 3, loss = 979176376597.19042969
# Validation score: 0.010544
# Iteration 4, loss = 921476085351.42651367
# Validation score: 0.250087
# Iteration 5, loss = 678939338304.96813965
# Validation score: 0.250278
# Iteration 6, loss = 669330297793.80725098
# Validation score: 0.232528
# Iteration 7, loss = 662734344459.26306152
# Validation score: 0.160682
# Iteration 8, loss = 672457279714.23901367
# Validation score: 0.215570
# Iteration 9, loss = 666777088124.32995605
# Validation score: 0.253333
# Iteration 10, loss = 665667439353.60107422
# Validation score: 0.176052
# Iteration 11, loss = 662182312620.68090820
# Validation score: 0.263457
# Iteration 12, loss = 660568472090.76025391
# Validation score: 0.176352
# Iteration 13, loss = 665260580551.61169434
# Validation score: 0.267875
# Iteration 14, loss = 660553267314.93041992
# Validation score: 0.221419
# Iteration 15, loss = 663196340606.02453613
# Validation score: 0.196411
# Iteration 16, loss = 656512165870.71398926
# Validation score: 0.204311
# Iteration 17, loss = 660100318512.60510254
# Validation score: 0.235962
# Iteration 18, loss = 661976573777.22949219
# Validation score: -0.022068
# Iteration 19, loss = 657425768038.61218262
# Validation score: 0.214124
# Iteration 20, loss = 659216063887.75744629
# Validation score: 0.276820
# Iteration 21, loss = 654561496005.75695801
# Validation score: 0.275637
# Iteration 22, loss = 658286267729.91992188
# Validation score: 0.262877
# Iteration 23, loss = 653555737921.80017090
# Validation score: 0.209563
# Iteration 24, loss = 650654493557.97888184
# Validation score: 0.273709
# Iteration 25, loss = 647375692581.31018066
# Validation score: 0.274895
# Iteration 26, loss = 647380044461.50683594
# Validation score: 0.288327
# Iteration 27, loss = 644474925860.08874512
# Validation score: 0.277659
# Iteration 28, loss = 636965491176.79040527
# Validation score: 0.208180
# Iteration 29, loss = 636298742602.77893066
# Validation score: 0.272793
# Iteration 30, loss = 631719364755.35778809
# Validation score: 0.349678
# Iteration 31, loss = 627726864349.96276855
# Validation score: 0.336571
# Iteration 32, loss = 630385174882.98559570
# Validation score: 0.242959
# Iteration 33, loss = 631886946126.58972168
# Validation score: 0.310490
# Iteration 34, loss = 624404199918.99353027
# Validation score: 0.309884
# Iteration 35, loss = 628188107008.90197754
# Validation score: 0.346913
# Iteration 36, loss = 628533481726.45397949
# Validation score: 0.233978
# Iteration 37, loss = 627740659029.87048340
# Validation score: 0.363251
# Iteration 38, loss = 627341564545.51599121
# Validation score: 0.349489
# Iteration 39, loss = 625631746856.08630371
# Validation score: 0.305630
# Iteration 40, loss = 624753668416.29760742
# Validation score: 0.318774
# Iteration 41, loss = 625161581349.20410156
# Validation score: 0.371110
# Iteration 42, loss = 619874142216.43505859
# Validation score: 0.380775
# Iteration 43, loss = 624868898813.64074707
# Validation score: 0.327166
# Iteration 44, loss = 617058535894.72082520
# Validation score: 0.380473
# Iteration 45, loss = 622889782547.00109863
# Validation score: 0.380222
# Iteration 46, loss = 622243131797.31665039
# Validation score: 0.352526
# Iteration 47, loss = 617711160117.98889160
# Validation score: 0.320346
# Iteration 48, loss = 614531836785.57971191
# Validation score: 0.346426
# Iteration 49, loss = 616998756847.69836426
# Validation score: 0.311046
# Iteration 50, loss = 618296369809.98547363
# Validation score: 0.359474
# Iteration 51, loss = 614846270272.08581543
# Validation score: 0.333451
# Iteration 52, loss = 613979102228.17260742
# Validation score: 0.381804
# Iteration 53, loss = 617197354644.50830078
# Validation score: 0.376870
# Iteration 54, loss = 614401834333.64880371
# Validation score: 0.354039
# Iteration 55, loss = 612719255756.86499023
# Validation score: 0.315409
# Iteration 56, loss = 611747926596.50476074
# Validation score: 0.379854
# Iteration 57, loss = 613636662376.93103027
# Validation score: 0.350839
# Iteration 58, loss = 613551855973.40466309
# Validation score: 0.363802
# Iteration 59, loss = 608202587770.45007324
# Validation score: 0.390040
# Iteration 60, loss = 612590625529.00024414
# Validation score: 0.397762
# Iteration 61, loss = 611153197047.86242676
# Validation score: 0.375735
# Iteration 62, loss = 611846774034.82446289
# Validation score: 0.397839
# Iteration 63, loss = 609418643477.78942871
# Validation score: 0.345001
# Iteration 64, loss = 608477049217.41564941
# Validation score: 0.337139
# Iteration 65, loss = 612706646214.65295410
# Validation score: 0.372656
# Iteration 66, loss = 609956979741.41833496
# Validation score: 0.401096
# Iteration 67, loss = 607635801441.73291016
# Validation score: 0.366554
# Iteration 68, loss = 610023644240.90393066
# Validation score: 0.276853
# Iteration 69, loss = 606979464485.27624512
# Validation score: 0.379706
# Iteration 70, loss = 606613171313.87316895
# Validation score: 0.398169
# Iteration 71, loss = 608457412962.31042480
# Validation score: 0.317400
# Iteration 72, loss = 604151628456.74230957
# Validation score: 0.404866
# Iteration 73, loss = 604791812090.82971191
# Validation score: 0.278378
# Iteration 74, loss = 606144789938.75109863
# Validation score: 0.388668
# Iteration 75, loss = 607253011055.08410645
# Validation score: 0.315403
# Iteration 76, loss = 609644698237.12231445
# Validation score: 0.339320
# Iteration 77, loss = 608013802004.86425781
# Validation score: 0.287118
# Iteration 78, loss = 607396340327.61840820
# Validation score: 0.269642
# Iteration 79, loss = 605359935065.34960938
# Validation score: 0.365964
# Iteration 80, loss = 606657693020.44567871
# Validation score: 0.401525
# Iteration 81, loss = 606049287043.55883789
# Validation score: 0.399136
# Iteration 82, loss = 604734314476.29064941
# Validation score: 0.343077
# Iteration 83, loss = 604779737604.87634277
# Validation score: 0.406179
# Iteration 84, loss = 603914241838.38793945
# Validation score: 0.388341
# Iteration 85, loss = 603794499086.23278809
# Validation score: 0.406635
# Iteration 86, loss = 602492287734.56274414
# Validation score: 0.367493
# Iteration 87, loss = 602179348507.37634277
# Validation score: 0.393004
# Iteration 88, loss = 604625599533.23986816
# Validation score: 0.401771
# Iteration 89, loss = 604959045971.92297363
# Validation score: 0.404071
# Iteration 90, loss = 602358678894.68676758
# Validation score: 0.399581
# Iteration 91, loss = 601666045415.51892090
# Validation score: 0.396155
# Iteration 92, loss = 603183268222.65039062
# Validation score: 0.408119
# Iteration 93, loss = 602196908453.69592285
# Validation score: 0.376551
# Iteration 94, loss = 601653513474.54431152
# Validation score: 0.361941
# Iteration 95, loss = 602999654294.49633789
# Validation score: 0.378287
# Iteration 96, loss = 603263711131.05004883
# Validation score: 0.343857
# Iteration 97, loss = 600281914631.09167480
# Validation score: 0.393229
# Iteration 98, loss = 597930267069.33374023
# Validation score: 0.398100
# Iteration 99, loss = 601860841238.34594727
# Validation score: 0.400030
# Iteration 100, loss = 601095193496.12731934
# Validation score: 0.377202
# Iteration 101, loss = 599609335855.31018066
# Validation score: 0.167681
# Iteration 102, loss = 600476701207.71936035
# Validation score: 0.379098
# Iteration 103, loss = 596726869275.39270020
# Validation score: 0.267732
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(batch_size=32, early_stopping=True,
#              hidden_layer_sizes=(64, 32, 16, 8), random_state=0, verbose=True)

# %%
#| hide
pickle.dump(nn, open("nn.pickle", "wb"))

# %%
#| hide
nn = pickle.load(open("nn.pickle", "rb"))

# %%
nn.score(X_valid, y_valid)
# Out:
# 0.44646501729966925

# %%
pd.Series(nn.validation_scores_).plot()
# Out:
# <Axes: >

# %%
sanity_checks(nn)
# Out:
# /tmp/ipykernel_121093/2726626927.py:36: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Spatial Boosted Random Forest

# %%
from knn_spatial_boost.core import KNNSpatialBooster

# %%
#| notest
boosted_rf = KNNSpatialBooster(
    n_neighbors=1,
    temperature=0,
    n_loops=1,
    spatial_features=[0, 1],
    remove_target_spatial_cols=True,
    remove_neighbor_spatial_cols=True,
    estimator=RandomForestRegressor(max_depth=10, random_state=0),
)

boosted_rf.fit(X_train, y_train)
# Out:
# Running loop #0

# %%
#| hide
pickle.dump(boosted_rf, open("boosted_rf.pickle", "wb"))

# %%
#| hide
boosted_rf = pickle.load(open("boosted_rf.pickle", "rb"))

# %%
boosted_rf.score(X_valid, y_valid)
# Out:
# 0.6928691169662196

# %%
sanity_checks(boosted_rf, set_color_bounds=True)
# Out:
# /tmp/ipykernel_121093/2726626927.py:36: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Spatial Boosted Neural Network
#
# After getting vertical and horizontal patterns using Random Forest and concluding we need a lot more training time to fit a neural network to the data,

# %%
#| notest
boosted_nn = KNNSpatialBooster(
    n_neighbors=1,
    temperature=0,
    n_loops=1,
    spatial_features=[0, 1],
    remove_target_spatial_cols=True,
    remove_neighbor_spatial_cols=True,
    estimator=MLPRegressor(
        hidden_layer_sizes=(32, 16, 8),
        warm_start=True,
        early_stopping=True,
        tol=1e-10,
        n_iter_no_change=20,
        verbose=True,
        max_iter=200,
        batch_size=32,
        random_state=0
    ),
)

boosted_nn.fit(X_train, y_train)
# Out:
# Running loop #0
# Iteration 1, loss = 697029229639.85302734
# Validation score: 0.367830
# Iteration 2, loss = 661979512876.12695312
# Validation score: 0.386610
# Iteration 3, loss = 653723562047.84448242
# Validation score: 0.393308
# Iteration 4, loss = 649417018375.94116211
# Validation score: 0.392419
# Iteration 5, loss = 644579241836.53015137
# Validation score: 0.397926
# Iteration 6, loss = 646732506500.05273438
# Validation score: 0.397698
# Iteration 7, loss = 642856265391.55834961
# Validation score: 0.389305
# Iteration 8, loss = 645179313061.56860352
# Validation score: 0.398760
# Iteration 9, loss = 643088102182.25659180
# Validation score: 0.400263
# Iteration 10, loss = 636943096546.90576172
# Validation score: 0.396539
# Iteration 11, loss = 639318399117.64257812
# Validation score: 0.394885
# Iteration 12, loss = 640513801452.49877930
# Validation score: 0.403317
# Iteration 13, loss = 639942349255.80932617
# Validation score: 0.372539
# Iteration 14, loss = 638569403195.36828613
# Validation score: 0.403002
# Iteration 15, loss = 638713059649.73632812
# Validation score: 0.403857
# Iteration 16, loss = 636771964984.85974121
# Validation score: 0.406003
# Iteration 17, loss = 630087555217.79455566
# Validation score: 0.404983
# Iteration 18, loss = 630615474329.46655273
# Validation score: 0.401569
# Iteration 19, loss = 629889650578.53784180
# Validation score: 0.402530
# Iteration 20, loss = 629642902040.30725098
# Validation score: 0.417533
# Iteration 21, loss = 622652452138.68957520
# Validation score: 0.394111
# Iteration 22, loss = 621072019299.94946289
# Validation score: 0.408591
# Iteration 23, loss = 618615042108.23254395
# Validation score: 0.423975
# Iteration 24, loss = 608165701759.84741211
# Validation score: 0.452285
# Iteration 25, loss = 588075639172.03393555
# Validation score: 0.451635
# Iteration 26, loss = 571320027188.58984375
# Validation score: 0.377478
# Iteration 27, loss = 555245524113.59582520
# Validation score: 0.498145
# Iteration 28, loss = 539130250850.15966797
# Validation score: 0.532345
# Iteration 29, loss = 532125593724.17761230
# Validation score: 0.478776
# Iteration 30, loss = 539276004596.57330322
# Validation score: 0.508915
# Iteration 31, loss = 527313203718.58465576
# Validation score: 0.512927
# Iteration 32, loss = 523569171585.37860107
# Validation score: 0.543218
# Iteration 33, loss = 524378574685.40222168
# Validation score: 0.542918
# Iteration 34, loss = 514829603483.16461182
# Validation score: 0.474700
# Iteration 35, loss = 517162667293.00988770
# Validation score: 0.525396
# Iteration 36, loss = 510746346168.16778564
# Validation score: 0.560246
# Iteration 37, loss = 510106580463.12786865
# Validation score: 0.552041
# Iteration 38, loss = 506538492128.52984619
# Validation score: 0.235498
# Iteration 39, loss = 514438007840.25878906
# Validation score: 0.569925
# Iteration 40, loss = 513844914769.65753174
# Validation score: 0.535021
# Iteration 41, loss = 519564708388.36291504
# Validation score: -0.339476
# Iteration 42, loss = 519223817635.23260498
# Validation score: 0.548351
# Iteration 43, loss = 506628530925.82153320
# Validation score: 0.571125
# Iteration 44, loss = 518118644817.66125488
# Validation score: 0.442895
# Iteration 45, loss = 521881076066.06579590
# Validation score: 0.523842
# Iteration 46, loss = 522467874633.59100342
# Validation score: 0.533707
# Iteration 47, loss = 503491079639.58251953
# Validation score: 0.517539
# Iteration 48, loss = 502892058689.13226318
# Validation score: 0.582493
# Iteration 49, loss = 494571688446.40716553
# Validation score: 0.591245
# Iteration 50, loss = 504321995448.71301270
# Validation score: 0.311832
# Iteration 51, loss = 504839660361.41241455
# Validation score: 0.590583
# Iteration 52, loss = 500689303603.46813965
# Validation score: 0.599120
# Iteration 53, loss = 494387730984.18572998
# Validation score: 0.527202
# Iteration 54, loss = 495187759054.16644287
# Validation score: 0.596745
# Iteration 55, loss = 482495545484.96154785
# Validation score: 0.531562
# Iteration 56, loss = 487402101735.54028320
# Validation score: 0.584770
# Iteration 57, loss = 499365058859.84729004
# Validation score: -0.074774
# Iteration 58, loss = 507773454709.90283203
# Validation score: 0.592802
# Iteration 59, loss = 505835791502.99133301
# Validation score: 0.584862
# Iteration 60, loss = 513641436509.74322510
# Validation score: 0.602698
# Iteration 61, loss = 490909180672.89465332
# Validation score: 0.528967
# Iteration 62, loss = 493238123835.73352051
# Validation score: 0.405374
# Iteration 63, loss = 490571925358.97509766
# Validation score: 0.581392
# Iteration 64, loss = 495757933060.40948486
# Validation score: 0.616680
# Iteration 65, loss = 532313231510.27227783
# Validation score: 0.562426
# Iteration 66, loss = 505576659225.07720947
# Validation score: 0.495200
# Iteration 67, loss = 528881122956.41754150
# Validation score: 0.585783
# Iteration 68, loss = 494668053890.74169922
# Validation score: 0.631300
# Iteration 69, loss = 532155854125.86358643
# Validation score: 0.471740
# Iteration 70, loss = 550017739221.08312988
# Validation score: 0.384404
# Iteration 71, loss = 547691074423.60852051
# Validation score: 0.520721
# Iteration 72, loss = 547849312514.48693848
# Validation score: 0.420552
# Iteration 73, loss = 538271081035.42651367
# Validation score: 0.412283
# Iteration 74, loss = 503463440110.65014648
# Validation score: 0.578497
# Iteration 75, loss = 486692430907.10217285
# Validation score: 0.544060
# Iteration 76, loss = 486509286454.66760254
# Validation score: 0.308371
# Iteration 77, loss = 515589217332.51293945
# Validation score: 0.323750
# Iteration 78, loss = 483471643112.05200195
# Validation score: 0.602762
# Iteration 79, loss = 501682530563.43829346
# Validation score: 0.605224
# Iteration 80, loss = 483883067945.53070068
# Validation score: 0.599565
# Iteration 81, loss = 496824425257.14447021
# Validation score: 0.560344
# Iteration 82, loss = 513400953444.30670166
# Validation score: 0.593284
# Iteration 83, loss = 486700762488.01202393
# Validation score: 0.471061
# Iteration 84, loss = 512390089352.93292236
# Validation score: 0.581134
# Iteration 85, loss = 498519660668.18017578
# Validation score: 0.609858
# Iteration 86, loss = 489962861593.34716797
# Validation score: 0.605475
# Iteration 87, loss = 505523246335.42657471
# Validation score: 0.594305
# Iteration 88, loss = 512213907216.21374512
# Validation score: 0.530928
# Iteration 89, loss = 476239500342.13403320
# Validation score: 0.389498
# Validation score did not improve more than tol=0.000000 for 20 consecutive epochs. Stopping.

# %%
pd.Series(boosted_nn.estimator.validation_scores_).plot()
# Out:
# <Axes: >

# %%
#| hide
pickle.dump(boosted_nn, open("boosted_nn.pickle", "wb"))

# %%
#| hide
boosted_nn = pickle.load(open("boosted_nn.pickle", "rb"))

# %%
boosted_nn.score(X_valid, y_valid)
# Out:
# 0.5910108769994615

# %%
sanity_checks(boosted_nn, set_color_bounds=True)
# Out:
# /tmp/ipykernel_121093/2726626927.py:36: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Conclusion
#
# |Model                     |Time to train|Score|BH check                        |Santa Cruz and Sion check                  |
# |--------------------------|-------------|-----|--------------------------------|---------------------------------|
# |Random Forest             |35.1s        |0.713|Vertical and horizontal patterns|Colapsing curves                 |
# |KNN                       |0.3s         |0.448|Random smooth surface           |Super high variance              |
# |Neural Network            |7m42.4s      |0.446|Random smooth surface           |Correct curve order but same price for different places and almost constant over time|
# |Spatial Boosted Random Forest |46.5s        |0.693|Seems natural                   |Colapsing curves                 |
# |Spatial Boosted Neural Network|3m54.2s      |0.591|Seems natural                   |Correct order and arguable price evolution and price difference between places|

# %% [markdown]
# Random Forest had the best score but with a little bit more investigation we see a bad geospatial generalization and no price difference when adding more rooms. It seems to overfit but due to a lack of data and not to a model inability. We need more spatial features like distance to the nearest city center, hospital, school, public transportation, etc.
#
# KNN had the best time to train but struggles with all other evaluation criteria.
#
# Neural Network seems to underfit. It's expected given the time to train and the complexity of understanding price fluctuation given only coordinates. It's possible to fit a neural network with this data but only with a lot more time to train.
#
# Instead of adding spatial features like distance to the nearest city center, I decided to use KNN to increase model spatial awareness by adding neighbors as features.
#
# Spatial Boosted Random Forest had better geospatial generalization but again seems to overfit due to lack of data.
#
# As neural networks have greater generalization capacity, in the end Spatial Boosted Neural Network was the model that best managed to learn the patterns even with little data. It had the best qualitative performance even scoring worse than other models.

# %% [markdown]
# ## Improvements
#
# - Generate a GIF to show price evolution throw time.
# - Compare computational efficiency.
# - Try other dataset to figure out which kind of problem suites better with the technique.
# - Implement neighbor randomness to improve model generalization.
# - Identify the way this method affect the base model (needs more tuning?).
# - Add a online demo for portifolio purposes.
